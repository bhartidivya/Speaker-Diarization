# %% [markdown]
# # Fine-tuning pyannote Segmentation
#
# This notebook prepares a domain-adaptation experiment for speaker diarization on consultation audio. It starts from a pretrained pyannote segmentation model, configures the dataset-specific segmentation task, and trains the model with checkpointing and early stopping.

# %% [markdown]
# ## Environment Setup
#
# Install the pyannote dependencies required for loading pretrained models and running the fine-tuning workflow. In Colab, run this cell before importing pyannote modules.

# %%
# !pip install pyannote.audio --quiet
# !pip install gdown --quiet

# %% [markdown]
# ## Load the Pretrained Segmentation Model
#
# The experiment uses `pyannote/segmentation` as the starting checkpoint. The Hugging Face token is read from the `HF_TOKEN` environment variable so credentials are not stored in the notebook.

# %%
from pyannote.audio import Model
import os

HF_TOKEN = os.environ.get("HF_TOKEN")
if not HF_TOKEN:
    raise ValueError("Set the HF_TOKEN environment variable before loading pyannote models.")

model = Model.from_pretrained("pyannote/segmentation", use_auth_token=HF_TOKEN)

# %% [markdown]
# ## Configure the Segmentation Task
#
# This cell attaches a `Segmentation` task to the pretrained model. The dataset path should point to the consultation audio prepared for training, and the model duration is reused so the fine-tuning windows match the pretrained model specification.

# %%
from pyannote.audio.tasks import Segmentation
# dataset='/content/drive/MyDrive/Speech_assignment/audio/day1_consultation01_doctor.wav'
task = Segmentation(
    dataset='/content/drive/MyDrive/Speech_assignment/audio/day1_consultation01_doctor.wav',
    duration=model.specifications.duration,
    max_num_speakers=1, #/len(model.specifications.classes),
    batch_size=32,
    num_workers=2,
    loss="bce",
    vad_loss="bce")
model.task = task
model.prepare_data()
model.setup()

# %% [markdown]
# ## Train with Checkpointing and Early Stopping
#
# The optimizer is set to Adam with a learning rate of `1e-4`. Validation monitoring comes from the pyannote task, while `ModelCheckpoint` keeps the best epoch and `EarlyStopping` stops training when validation performance stops improving.

# %%
from types import MethodType
from torch.optim import Adam
from pytorch_lightning.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    RichProgressBar,
)

# we use Adam optimizer with 1e-4 learning rate
def configure_optimizers(self):
    return Adam(self.parameters(), lr=1e-4)

model.configure_optimizers = MethodType(configure_optimizers, model)

# we monitor diarization error rate on the validation set
# and use to keep the best checkpoint and stop early
monitor, direction = task.val_monitor
checkpoint = ModelCheckpoint(
    monitor=monitor,
    mode=direction,
    save_top_k=1,
    every_n_epochs=1,
    save_last=False,
    save_weights_only=False,
    filename="{epoch}",
    verbose=False,
)
early_stopping = EarlyStopping(
    monitor=monitor,
    mode=direction,
    min_delta=0.0,
    patience=10,
    strict=True,
    verbose=False,
)

callbacks = [RichProgressBar(), checkpoint, early_stopping]

# we train for at most 20 epochs (might be shorter in case of early stopping)
from pytorch_lightning import Trainer
trainer = Trainer(accelerator="gpu",
                  callbacks=callbacks,
                  max_epochs=20,
                  gradient_clip_val=0.5)
trainer.fit(model)

# %% [markdown]
# ## Save the Best Model Path
#
# After training, `checkpoint.best_model_path` stores the path to the best checkpoint selected by the validation metric. This path can be used later for evaluation or inference.

# %%
finetuned_model = checkpoint.best_model_path
